# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('all_tables.csv')
file.head()
# Out:
#    Pos                    Team  GP   W   L   SW  GF  GA   GD Pts  \
# 0  1.0        Tampa Bay Mutiny  32  19  12  1.0  66  51  +15  58
# 1  2.0             D.C. United  32  15  16  1.0  62  56   +6  46
# 2  3.0        NY/NJ MetroStars  32  12  17  3.0  45  47   −2  39
# 3  4.0           Columbus Crew  32  11  17  4.0  59  60   −1  37
# 4  5.0  New England Revolution  32   9  17  6.0  43  56  −13  33
#
#   Qualification          Conference  Year  SL   D Head-to-head  PPG
# 0      Playoffs  Eastern Conference  1996 NaN NaN          NaN  NaN
# 1      Playoffs  Eastern Conference  1996 NaN NaN          NaN  NaN
# 2      Playoffs  Eastern Conference  1996 NaN NaN          NaN  NaN
# 3      Playoffs  Eastern Conference  1996 NaN NaN          NaN  NaN
# 4           NaN  Eastern Conference  1996 NaN NaN          NaN  NaN

# %%
players = pd.read_csv('all_players.csv')
players.head()

fish = players['Player'] == 'Carlos Ruiz'

# %%
players[fish].describe()
# Out:
#               GP         GS         MINS          G          A        SHTS  \
# count  18.000000  18.000000    18.000000  18.000000  18.000000   18.000000
# mean   11.222222   9.500000   868.388889   5.833333   1.055556   30.888889
# std    10.044346   9.696876   854.376838   6.706011   1.661757   31.940918
# min     0.000000   0.000000     0.000000   0.000000   0.000000    0.000000
# 25%     2.000000   2.000000   185.250000   1.000000   0.000000    4.500000
# 50%     9.500000   5.500000   547.500000   2.000000   0.000000   15.500000
# 75%    19.750000  18.000000  1576.750000  10.250000   2.000000   57.750000
# max    27.000000  26.000000  2376.000000  24.000000   5.000000  100.000000
#
#              SOG        GWG        HmG        RdG  ...        HmA        RdA  \
# count  18.000000  18.000000  18.000000  18.000000  ...  18.000000  18.000000
# mean   16.111111   1.611111   3.722222   2.111111  ...   0.777778   0.277778
# ...

# %%
players
# Out:
#                   Player Club  POS  GP  GS  MINS   G   A  SHTS  SOG  ...  RdA  \
# 0           Roy Lassiter  TB     F  30  30  2580  27   4    76   49  ...    2
# 1         Raul Diaz Arce  DC     F  28  28  2351  23   2   100   49  ...    2
# 2        Eduardo Hurtado  LA     F  26  26  2323  21   7    87   56  ...    3
# 3                  Preki  KC     M  32  32  2880  18  13   140   61  ...    4
# 4          Brian McBride  CLB    F  28  28  2307  17   3    79   44  ...    1
# ...                  ...  ...  ...  ..  ..   ...  ..  ..   ...  ...  ...  ...
# 15762  Alejandro Pozuelo  NaN    M   1   1   120   0   0     5    0  ...    0
# 15763        Franco Jara  NaN    F   2   2   210   0   0     5    1  ...    0
# 15764          Andy Polo  NaN    M   1   1   105   0   0     6    3  ...    0
# 15765    Cristian Roldan  NaN    M   4   4   360   0   0     6    1  ...    0
# 15766       Joevin Jones  NaN  D-M   4   4   260   0   0     8    1  ...    0
#
# ...
