# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x**2
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.5, 0.9])
axes.plot(x, y, 'y')
fig.show()
# Out:
# C:\Users\juan98\AppData\Local\Temp\ipykernel_10468\880657249.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.2, 0.9])
axes.plot(x, y, 'b')
fig.show()
# Out:
# C:\Users\juan98\AppData\Local\Temp\ipykernel_10468\2519810368.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axes2 = fig.add_axes([0.2, 0.1, 0.4, 0.3])


axes.plot(x, y, 'b')
axes2.plot(y, x, 'r')

axes2.set_facecolor('gray')

fig.show()
# Out:
# C:\Users\juan98\AppData\Local\Temp\ipykernel_10468\2256696912.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
