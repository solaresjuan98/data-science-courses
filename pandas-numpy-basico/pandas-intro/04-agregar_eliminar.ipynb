# %%
import pandas as pd
import numpy as np

# %%
df_books = pd.read_csv('file1.csv')

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ## Drop columns

# %%
df_books.drop('Genre', axis=1, inplace=True)

# %%
df_books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year
# 0                  JJ Smith          4.7    17350      8  2016
# 1              Stephen King          4.6     2052     22  2011
# 2        Jordan B. Peterson          4.7    18979     15  2018
# 3             George Orwell          4.7    21424      6  2017
# 4  National Geographic Kids          4.8     7665     12  2019

# %%
df_books = df_books.drop('Year', axis = 1)
df_books.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\juan98\Documents\JUAN\cursos-varios\pandas-numpy-basico\pandas-intro\04-agregar_eliminar.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/juan98/Documents/JUAN/cursos-varios/pandas-numpy-basico/pandas-intro/04-agregar_eliminar.ipynb#ch0000008?line=0'>1</a> df_books = df_books.drop('Year', axis = 1)
#       <a href='vscode-notebook-cell:/e%3A/juan98/Documents/JUAN/cursos-varios/pandas-numpy-basico/pandas-intro/04-agregar_eliminar.ipynb#ch0000008?line=1'>2</a> df_books.head()
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4805'>4806</a> @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4806'>4807</a> def drop(
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4807'>4808</a>     self,
#    (...)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4814'>4815</a>     errors: str = "raise",
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4815'>4816</a> ):
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4816'>4817</a>     """
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4817'>4818</a>     Drop specified labels from rows or columns.
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4818'>4819</a>
#    (...)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4951'>4952</a>             weight  1.0     0.8
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4952'>4953</a>     """
# -> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4953'>4954</a>     return super().drop(
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4954'>4955</a>         labels=labels,
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4955'>4956</a>         axis=axis,
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4956'>4957</a>         index=index,
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4957'>4958</a>         columns=columns,
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4958'>4959</a>         level=level,
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4959'>4960</a>         inplace=inplace,
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4960'>4961</a>         errors=errors,
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/frame.py?line=4961'>4962</a>     )
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4264'>4265</a> for axis, labels in axes.items():
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4265'>4266</a>     if labels is not None:
# -> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4266'>4267</a>         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4268'>4269</a> if inplace:
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4269'>4270</a>     self._update_inplace(obj)
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4308'>4309</a>         new_axis = axis.drop(labels, level=level, errors=errors)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4309'>4310</a>     else:
# -> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4310'>4311</a>         new_axis = axis.drop(labels, errors=errors)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4311'>4312</a>     indexer = axis.get_indexer(new_axis)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4313'>4314</a> # Case for non-unique axis
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4314'>4315</a> else:
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=6641'>6642</a> if mask.any():
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=6642'>6643</a>     if errors != "ignore":
# -> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=6643'>6644</a>         raise KeyError(f"{list(labels[mask])} not found in axis")
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=6644'>6645</a>     indexer = indexer[~mask]
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=6645'>6646</a> return self.delete(indexer)
#
# KeyError: "['Year'] not found in axis"

# %%
del df_books['Price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# e:\juan98\Documents\JUAN\cursos-varios\pandas-numpy-basico\pandas-intro\04-agregar_eliminar.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/juan98/Documents/JUAN/cursos-varios/pandas-numpy-basico/pandas-intro/04-agregar_eliminar.ipynb#ch0000009?line=0'>1</a> del df_books['Price']
#       <a href='vscode-notebook-cell:/e%3A/juan98/Documents/JUAN/cursos-varios/pandas-numpy-basico/pandas-intro/04-agregar_eliminar.ipynb#ch0000009?line=1'>2</a> df_books
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\core\generic.py:4048, in NDFrame.__delitem__(self, key)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4042'>4043</a>             deleted = True
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4043'>4044</a> if not deleted:
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4044'>4045</a>     # If the above loop ran and didn't delete anything because
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4045'>4046</a>     # there was no match, this call should raise the appropriate
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4046'>4047</a>     # exception:
# -> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4047'>4048</a>     loc = self.axes[-1].get_loc(key)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4048'>4049</a>     self._mgr = self._mgr.idelete(loc)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/generic.py?line=4050'>4051</a> # delete from the caches
#
# File E:\Users\juan98\anaconda3\envs\pyenv\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///e%3A/Users/juan98/anaconda3/envs/pyenv/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'Price'

# %%
df_books.drop(0, axis =0).head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews
# 1     2052
# 2    18979

# %%
df_books.drop([0,1, 2], axis=0).head()
# Out:
#                                                 Name  \
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
#
#                      Author  User Rating  Reviews
# 3             George Orwell          4.7    21424
# 4  National Geographic Kids          4.8     7665
# 5       George R. R. Martin          4.4    12643
# 6       George R. R. Martin          4.7    19735
# 7               Amor Towles          4.7    19699

# %%
df_books.drop(range(0, 10), axis = 0).head(2)
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     User Rating  Reviews
# 10          4.6    23848
# 11          4.6      460

# %%
df_books['Nueva Columna'] = np.nan
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Nueva Columna
# 0                    JJ Smith          4.7    17350            NaN
# 1                Stephen King          4.6     2052            NaN
# 2          Jordan B. Peterson          4.7    18979            NaN
# 3               George Orwell          4.7    21424            NaN
# 4    National Geographic Kids          4.8     7665            NaN
# ..                        ...          ...      ...            ...
# 545               Jeff Kinney          4.9     9413            NaN
# 546               Jen Sincero          4.7    14331            NaN
# 547               Jen Sincero          4.7    14331            NaN
# 548               Jen Sincero          4.7    14331            NaN
# 549               Jen Sincero          4.7    14331            NaN
#
# [550 rows x 5 columns]

# %%
data = np.arange(0, df_books.shape[0])

# %%
df_books['Rango'] = data
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Rango
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ..     ...
# 545    545
# 546    546
# 547    547
# 548    548
# 549    549
#
# [550 rows x 8 columns]

# %% [markdown]
# # Add rows

# %%
df_books.append(df_books)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\juan98\Documents\JUAN\cursos-varios\pandas-numpy-basico\pandas-intro\04-agregar_eliminar.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/juan98/Documents/JUAN/cursos-varios/pandas-numpy-basico/pandas-intro/04-agregar_eliminar.ipynb#ch0000018?line=0'>1</a> df_books.append()
#
# TypeError: append() missing 1 required positional argument: 'other'
